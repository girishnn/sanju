# %% [markdown]
# <a href="https://colab.research.google.com/github/girishnn/sanju/blob/main/cie3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('/content/mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.drop('car name',axis=1)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
x=df.weight
x
# Out:
# 0      3504
# 1      3693
# 2      3436
# 3      3433
# 4      3449
#        ...
# 393    2790
# 394    2130
# 395    2295
# 396    2625
# 397    2720
# Name: weight, Length: 398, dtype: int64

# %%
y=df.mpg
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['weight']],df[['mpg']])

# %%
x_train
# Out:
#      weight
# 229    4220
# 372    2735
# 371    2525
# 47     3282
# 342    2385
# ..      ...
# 180    2671
# 293    1925
# 211    3820
# 150    2391
# 128    3336
#
# [298 rows x 1 columns]

# %%
x_test
# Out:
#      weight
# 232    4335
# 58     2126
# 317    2188
# 81     2288
# 6      4354
# ..      ...
# 115    4082
# 198    1795
# 41     4096
# 199    3651
# 328    3250
#
# [100 rows x 1 columns]

# %%
y_train
# Out:
#       mpg
# 229  16.0
# 372  27.0
# 371  29.0
# 47   19.0
# 342  30.0
# ..    ...
# 180  25.0
# 293  31.9
# 211  16.5
# 150  26.0
# 128  15.0
#
# [298 rows x 1 columns]

# %%
y_test
# Out:
#       mpg
# 232  16.0
# 58   25.0
# 317  34.3
# 81   28.0
# 6    14.0
# ..    ...
# 115  15.0
# 198  33.0
# 41   14.0
# 199  20.0
# 328  30.0
#
# [100 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)
x_pred
y_pred
# Out:
# array([[13.07823854],
#        [29.79541912],
#        [29.32621804],
#        [28.56944209],
#        [12.93445111],
#        [30.60516938],
#        [30.93815079],
#        [29.84082568],
#        [30.40840763],
#        [25.94342957],
#        [12.41984347],
#        [16.39291717],
#        [20.3054488 ],
#        [21.72061981],
#        [23.90013453],
#        [23.1584941 ],
#        [13.50960083],
#        [28.47862898],
#        [31.12734478],
#        [12.15497189],
#        [29.91650327],
#        [16.89995705],
#        [19.24596248],
#        [31.22572565],
#        [14.448003  ],
#        [30.93815079],
#        [22.00819467],
#        [27.57049785],
#        [16.52156908],
#        [32.07331471],
#        [32.26250869],
#        [33.67767971],
#        [17.656733  ],
#        [27.46454922],
#        [19.96489962],
#        [25.91315853],
#        [29.5759541 ],
#        [26.51101153],
#        [19.90435755],
#        [27.17697436],
#        [27.04832245],
# ...

# %%
y_test
# Out:
#       mpg
# 232  16.0
# 58   25.0
# 317  34.3
# 81   28.0
# 6    14.0
# ..    ...
# 115  15.0
# 198  33.0
# 41   14.0
# 199  20.0
# 328  30.0
#
# [100 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_absolute_error(x_test,y_pred)
mae=mean_squared_error(x_test,y_pred)
r2=r2_score(x_test,y_pred)

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# np.float64(54.222716950248916)

# %%
print(mse)
print(mae)
print(r2)
# Out:
# 2940.103033466811
# 9392194.927007515
# -11.747363338090047

# %%
plt.scatter(x_train,y_train,color='blue')
plt.plot(x_train,x_pred,color='red')
